# %%
from alpha_vantage.timeseries import TimeSeries
from pprint import pprint
import matplotlib
import matplotlib.pyplot as plt
ts = TimeSeries(key='NC7EK8P3FVXLI0LW', output_format='pandas')
data, meta_data = ts.get_intraday(symbol='ANZ.AX',interval='60min', outputsize='compact')
pprint(data.head(10))
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# date
# 2018-07-30 01:00:00    29.29   29.300  29.260     29.27   285029.0
# 2018-07-30 20:00:00    29.40   29.490  29.300     29.34        0.0
# 2018-07-30 21:00:00    29.34   29.370  29.280     29.35   470202.0
# 2018-07-30 22:00:00    29.35   29.360  29.255     29.33   292576.0
# 2018-07-30 23:00:00    29.33   29.370  29.330     29.34   395823.0
# 2018-07-31 00:00:00    29.33   29.345  29.260     29.30   343237.0
# 2018-07-31 01:00:00    29.29   29.390  29.250     29.35   856254.0
# 2018-07-31 20:00:00    29.32   29.330  29.100     29.11        0.0
# 2018-07-31 21:00:00    29.11   29.150  29.025     29.06   305219.0
# 2018-07-31 22:00:00    29.07   29.100  29.040     29.09   282755.0

# %%
'''Issue: Cannot figure out how to change the display of timezone to AU time yet'''
meta_data
# Out:
# {'1. Information': 'Intraday (60min) open, high, low, close prices and volume',
#  '2. Symbol': 'ANZ.AX',
#  '3. Last Refreshed': '2018-08-21 22:00:00',
#  '4. Interval': '60min',
#  '5. Output Size': 'Compact',
#  '6. Time Zone': 'US/Eastern'}

# %%
data
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# date
# 2018-07-30 01:00:00   29.290   29.300  29.260    29.270   285029.0
# 2018-07-30 20:00:00   29.400   29.490  29.300    29.340        0.0
# 2018-07-30 21:00:00   29.340   29.370  29.280    29.350   470202.0
# 2018-07-30 22:00:00   29.350   29.360  29.255    29.330   292576.0
# 2018-07-30 23:00:00   29.330   29.370  29.330    29.340   395823.0
# 2018-07-31 00:00:00   29.330   29.345  29.260    29.300   343237.0
# 2018-07-31 01:00:00   29.290   29.390  29.250    29.350   856254.0
# 2018-07-31 20:00:00   29.320   29.330  29.100    29.110        0.0
# 2018-07-31 21:00:00   29.110   29.150  29.025    29.060   305219.0
# 2018-07-31 22:00:00   29.070   29.100  29.040    29.090   282755.0
# 2018-07-31 23:00:00   29.080   29.100  29.030    29.070   253885.0
# 2018-08-01 00:00:00   29.065   29.090  29.050    29.080   359220.0
# 2018-08-01 01:00:00   29.080   29.080  28.990    29.000   835204.0
# ...

# %%
data.describe()
data['4. close'].plot()
plt.title('Hourly chart for ANZ')
plt.grid()
plt.show()

# %%
'''Site for stock price https://www.marketindex.com.au/asx/anz'''
# Out:
# 'Site for stock price https://www.marketindex.com.au/asx/anz'
